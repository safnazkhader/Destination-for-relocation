# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
new=pd.read_excel('average salary excel.xlsx')

# %%
new
# Out:
#                  COUNTRY Monthy SALARY+TAX($)  cost of living.Rank  \
# 0                  China              938.91                    49
# 1                 Sweden            2,807.55                    26
# 2              Singapore            4,293.54                    30
# 3              Australia            3,678.75                    17
# 4   United Arab Emirates            3,300.22                    34
# 5                 Brazil              414.62                    51
# 6                Germany            2,984.93                    29
# 7                Austria            2,579.59                    27
# 8                Finland            2,818.03                    22
# 9                 Canada            2,818.53                    21
# 10               Belgium            2,563.22                    25
# 11                 Chile              670.31                    46
# 12                Norway            3,286.54                    20
# ...

# %%
pd.set_option('display.max_rows', 2000)

pd.set_option('display.max_columns', 500)

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   COUNTRY                                61 non-null     object
#  1   Monthy SALARY+TAX($)                   61 non-null     object
#  2   cost of living.Rank                    61 non-null     int64
#  3   cost of living.Cost index              61 non-null     float64
#  4   cost of living.Monthly income(USD)     61 non-null     int64
#  5   cost of living.Purchasing power index  61 non-null     float64
#  6   currency rate.CURRENCY RATE(2023)      60 non-null     float64
#  7   inflation rate.inflation rate %        61 non-null     float64
#  8   GDP.GDP                                61 non-null     int64
#  9   literacy rate.literacy rate(%)         61 non-null     float64
# ...

# %%
rename_col={'cost of living.Rank':'cost of living','cost of living.Cost index':'cost index','cost of living.Monthly income(USD)':'monthly income($)','cost of living.Purchasing power index':'purchasing power index','currency rate.CURRENCY RATE(2023)':'currency rate','inflation rate.inflation rate %':'inflation rate(%)','GDP.GDP':'GDP','literacy rate.literacy rate(%)':'Litercay rate(%)','population.Population (2024)':'population','population.Migrants (net)':'migrants','skilled labour.SKILLED LABOUR ':'skilled labour','technology.Rank':'technology','unemployment.Unemploymentrate (%)':'unemployment'}

# %%
new=new.rename(columns=rename_col)

# %%
new
# Out:
#                  COUNTRY Monthy SALARY+TAX($)  cost of living  cost index  \
# 0                  China              938.91               49        51.5
# 1                 Sweden            2,807.55               26        82.4
# 2              Singapore            4,293.54               30        78.0
# 3              Australia            3,678.75               17        96.4
# 4   United Arab Emirates            3,300.22               34        72.1
# 5                 Brazil              414.62               51        49.8
# 6                Germany            2,984.93               29        79.5
# 7                Austria            2,579.59               27        80.9
# 8                Finland            2,818.03               22        90.2
# 9                 Canada            2,818.53               21        90.7
# 10               Belgium            2,563.22               25        83.7
# 11                 Chile              670.31               46        58.5
# ...

# %%
new.isnull().sum()
# Out:
# COUNTRY                          0
# Monthy SALARY+TAX($)             0
# cost of living                   0
# cost index                       0
# monthly income($)                0
# purchasing power index           0
# currency rate                    1
# inflation rate(%)                0
# GDP                              0
# Litercay rate(%)                 0
# population                       0
# migrants                         0
# skilled labour.SKILLED LABOUR    0
# technology                       0
# unemployment                     0
# dtype: int64

# %%
new['currency rate'].fillna(12.1,inplace=True)
# Out:
# C:\Users\noufa\AppData\Local\Temp\ipykernel_9048\3293588455.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
new.isnull().sum()
# Out:
# COUNTRY                          0
# Monthy SALARY+TAX($)             0
# cost of living                   0
# cost index                       0
# monthly income($)                0
# purchasing power index           0
# currency rate                    0
# inflation rate(%)                0
# GDP                              0
# Litercay rate(%)                 0
# population                       0
# migrants                         0
# skilled labour.SKILLED LABOUR    0
# technology                       0
# unemployment                     0
# dtype: int64

# %%
new['Monthy SALARY+TAX($)'] = new['Monthy SALARY+TAX($)'].str.strip()

# %%
new['Monthy SALARY+TAX($)'] = new['Monthy SALARY+TAX($)'].replace({',': ''}, regex=True).astype(float)
print(new)
# Out:
#                  COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 0                  China                938.91              49        51.5
# 1                 Sweden               2807.55              26        82.4
# 2              Singapore               4293.54              30        78.0
# 3              Australia               3678.75              17        96.4
# 4   United Arab Emirates               3300.22              34        72.1
# 5                 Brazil                414.62              51        49.8
# 6                Germany               2984.93              29        79.5
# 7                Austria               2579.59              27        80.9
# 8                Finland               2818.03              22        90.2
# 9                 Canada               2818.53              21        90.7
# 10               Belgium               2563.22              25        83.7
# ...

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   COUNTRY                        61 non-null     object
#  1   Monthy SALARY+TAX($)           61 non-null     float64
#  2   cost of living                 61 non-null     int64
#  3   cost index                     61 non-null     float64
#  4   monthly income($)              61 non-null     int64
#  5   purchasing power index         61 non-null     float64
#  6   currency rate                  61 non-null     float64
#  7   inflation rate(%)              61 non-null     float64
#  8   GDP                            61 non-null     int64
#  9   Litercay rate(%)               61 non-null     float64
#  10  population                     61 non-null     int64
#  11  migrants                       61 non-null     int64
# ...

# %%
#what is the minimum wage of the countries where it is higher than the avg salary?

# %%
avg_sal=new['Monthy SALARY+TAX($)'].mean()
avg_sal
# Out:
# 1504.0199999999998

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   COUNTRY                        61 non-null     object
#  1   Monthy SALARY+TAX($)           61 non-null     float64
#  2   cost of living                 61 non-null     int64
#  3   cost index                     61 non-null     float64
#  4   monthly income($)              61 non-null     int64
#  5   purchasing power index         61 non-null     float64
#  6   currency rate                  61 non-null     float64
#  7   inflation rate(%)              61 non-null     float64
#  8   GDP                            61 non-null     int64
#  9   Litercay rate(%)               61 non-null     float64
#  10  population                     61 non-null     int64
#  11  migrants                       61 non-null     int64
# ...

# %%
new1=new[avg_sal<new['Monthy SALARY+TAX($)']]

# %%
new1
# Out:
#                  COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 1                 Sweden               2807.55              26        82.4
# 2              Singapore               4293.54              30        78.0
# 3              Australia               3678.75              17        96.4
# 4   United Arab Emirates               3300.22              34        72.1
# 6                Germany               2984.93              29        79.5
# 7                Austria               2579.59              27        80.9
# 8                Finland               2818.03              22        90.2
# 9                 Canada               2818.53              21        90.7
# 10               Belgium               2563.22              25        83.7
# 12                Norway               3286.54              20        90.8
# 13               Ireland               3073.35              11       102.7
# ...

# %%
import plotly.express as px
fig = px.histogram(new, x="COUNTRY", y="Monthy SALARY+TAX($)")
fig.show()
# Out:
# <div>                            <div id="9dda76d9-57d5-4b3c-8b8b-f63b09c840b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dda76d9-57d5-4b3c-8b8b-f63b09c840b0")) {                    Plotly.newPlot(                        "9dda76d9-57d5-4b3c-8b8b-f63b09c840b0",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of Monthy SALARY+TAX($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["China","Sweden","Singapore","Australia","United Arab Emirates","Brazil","Germany","Austria","Finland","Canada","Belgium","Chile","Norway","Ireland","Bulga
# ...

# %%
#list the top 5 countries with highest avg salary

# %%
sorted_new = new.sort_values(by="Monthy SALARY+TAX($)", ascending=False)

# %%
sorted_new
# Out:
#                  COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 20            Luxembourg               5640.97              16        97.5
# 2              Singapore               4293.54              30        78.0
# 40                 Qatar               4086.40              31        76.9
# 3              Australia               3678.75              17        96.4
# 17               Denmark               3596.29              10       103.9
# 4   United Arab Emirates               3300.22              34        72.1
# 12                Norway               3286.54              20        90.8
# 18        United Kingdom               3105.98              19        92.9
# 13               Ireland               3073.35              11       102.7
# 6                Germany               2984.93              29        79.5
# 24           New Zealand               2962.58              18        94.3
# ...

# %%
l=sorted_new.head(10)

# %%
print(l)
# Out:
#                  COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 20            Luxembourg               5640.97              16        97.5
# 2              Singapore               4293.54              30        78.0
# 40                 Qatar               4086.40              31        76.9
# 3              Australia               3678.75              17        96.4
# 17               Denmark               3596.29              10       103.9
# 4   United Arab Emirates               3300.22              34        72.1
# 12                Norway               3286.54              20        90.8
# 18        United Kingdom               3105.98              19        92.9
# 13               Ireland               3073.35              11       102.7
# 6                Germany               2984.93              29        79.5
#
#     monthly income($)  purchasing power index  currency rate  \
# 20               7364                   112.9         -1.095
# ...

# %%
import plotly.express as px
fig = px.histogram(l, x="COUNTRY", y="Monthy SALARY+TAX($)")
fig.show()
# Out:
# <div>                            <div id="34ab6bf9-2a6a-42be-8b6d-35fc4c665b33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34ab6bf9-2a6a-42be-8b6d-35fc4c665b33")) {                    Plotly.newPlot(                        "34ab6bf9-2a6a-42be-8b6d-35fc4c665b33",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of Monthy SALARY+TAX($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Luxembourg","Singapore","Qatar","Australia","Denmark","United Arab Emirates","Norway","United Kingdom","Ireland","Germany"],"xaxis":"x","y":[5640.97,4293.
# ...

# %%
correlation = new[['Litercay rate(%)', 'Monthy SALARY+TAX($)']].corr()
print(correlation)
# Out:
#                       Litercay rate(%)  Monthy SALARY+TAX($)
# Litercay rate(%)               1.00000               0.33786
# Monthy SALARY+TAX($)           0.33786               1.00000

# %%
#top 10 countries with less cost of living

# %%
sorted_new = new.sort_values(by="cost of living", ascending=True)

# %%
sorted_new
# Out:
#                  COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 22                Israel               2703.21               8       105.3
# 17               Denmark               3596.29              10       103.9
# 13               Ireland               3073.35              11       102.7
# 20            Luxembourg               5640.97              16        97.5
# 3              Australia               3678.75              17        96.4
# 24           New Zealand               2962.58              18        94.3
# 18        United Kingdom               3105.98              19        92.9
# 12                Norway               3286.54              20        90.8
# 9                 Canada               2818.53              21        90.7
# 8                Finland               2818.03              22        90.2
# 10               Belgium               2563.22              25        83.7
# ...

# %%
sorted_new.head(10)
# Out:
#            COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 22          Israel               2703.21               8       105.3
# 17         Denmark               3596.29              10       103.9
# 13         Ireland               3073.35              11       102.7
# 20      Luxembourg               5640.97              16        97.5
# 3        Australia               3678.75              17        96.4
# 24     New Zealand               2962.58              18        94.3
# 18  United Kingdom               3105.98              19        92.9
# 12          Norway               3286.54              20        90.8
# 9           Canada               2818.53              21        90.7
# 8          Finland               2818.03              22        90.2
#
#     monthly income($)  purchasing power index  currency rate  \
# 22               4585                    65.1          2.003
# 17               6113                    87.9          1.813
# ...

# %%
cl=sorted_new.head(10)

# %%
cl
# Out:
#            COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 22          Israel               2703.21               8       105.3
# 17         Denmark               3596.29              10       103.9
# 13         Ireland               3073.35              11       102.7
# 20      Luxembourg               5640.97              16        97.5
# 3        Australia               3678.75              17        96.4
# 24     New Zealand               2962.58              18        94.3
# 18  United Kingdom               3105.98              19        92.9
# 12          Norway               3286.54              20        90.8
# 9           Canada               2818.53              21        90.7
# 8          Finland               2818.03              22        90.2
#
#     monthly income($)  purchasing power index  currency rate  \
# 22               4585                    65.1          2.003
# 17               6113                    87.9          1.813
# ...

# %%
import plotly.express as px
fig = px.histogram(cl, x="COUNTRY", y="cost of living")
fig.show()
# Out:
# <div>                            <div id="3ee23819-55d9-44ee-80e4-28e63677af97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ee23819-55d9-44ee-80e4-28e63677af97")) {                    Plotly.newPlot(                        "3ee23819-55d9-44ee-80e4-28e63677af97",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of cost of living=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Israel","Denmark","Ireland","Luxembourg","Australia","New Zealand","United Kingdom","Norway","Canada","Finland"],"xaxis":"x","y":[8,10,11,16,17,18,19,20,21,22],
# ...

# %%
PP = new.sort_values(by="purchasing power index", ascending=True).head(10)

# %%
PP
# Out:
#         COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 54        Nepal                215.71              99        26.3
# 57      Nigeria                148.16              79        32.4
# 56        Kenya                360.47              83        31.4
# 59     Pakistan                182.06             108        21.3
# 44      Morocco                418.32              63        40.6
# 53  El Salvador                501.07              54        49.0
# 60   Bangladesh                239.43              95        28.5
# 31        India                608.55             106        23.6
# 39  Philippines                378.58              67        37.2
# 42      Tunisia                291.18              93        29.6
#
#     monthly income($)  purchasing power index  currency rate  \
# 54                114                     6.5          0.832
# 57                161                     7.4          2.860
# ...

# %%
import plotly.express as px
fig = px.histogram(PP, x="COUNTRY", y="purchasing power index")
fig.show()
# Out:
# <div>                            <div id="8831fd95-a50f-484c-bc99-b196720f1e19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8831fd95-a50f-484c-bc99-b196720f1e19")) {                    Plotly.newPlot(                        "8831fd95-a50f-484c-bc99-b196720f1e19",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of purchasing power index=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Nepal","Nigeria","Kenya","Pakistan","Morocco","El Salvador","Bangladesh","India","Philippines","Tunisia"],"xaxis":"x","y":[6.5,7.4,8.4,8.8,11.3,12.5,12.
# ...

# %%
CR = new.sort_values(by="currency rate", ascending=False).head(10)

# %%
CR
# Out:
#         COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 49    Sri Lanka                206.76              97        27.5
# 58        Libya                326.36             104        24.4
# 31        India                608.55             106        23.6
# 46      Georgia                505.05              90        30.4
# 60   Bangladesh                239.43              95        28.5
# 39  Philippines                378.58              67        37.2
# 56        Kenya                360.47              83        31.4
# 0         China                938.91              49        51.5
# 23   Costa Rica                964.67              39        67.2
# 43   Kazakhstan                568.13              70        36.6
#
#     monthly income($)  purchasing power index  currency rate  \
# 49                295                    16.0         12.100
# 58                631                    38.7         10.156
# ...

# %%
import plotly.express as px
fig = px.histogram(CR, x="COUNTRY", y="currency rate")
fig.show()
# Out:
# <div>                            <div id="050e012a-ecd4-42d6-8d79-efd3930ee055" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("050e012a-ecd4-42d6-8d79-efd3930ee055")) {                    Plotly.newPlot(                        "050e012a-ecd4-42d6-8d79-efd3930ee055",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of currency rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Sri Lanka","Libya","India","Georgia","Bangladesh","Philippines","Kenya","China","Costa Rica","Kazakhstan"],"xaxis":"x","y":[12.1,10.156,7.827,7.474,6.025,5.568,5
# ...

# %%
GDP = new.sort_values(by="GDP", ascending=False).head(10)

# %%
GDP
# Out:
#        COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 20  Luxembourg               5640.97              16        97.5
# 13     Ireland               3073.35              11       102.7
# 12      Norway               3286.54              20        90.8
# 40       Qatar               4086.40              31        76.9
# 2    Singapore               4293.54              30        78.0
# 17     Denmark               3596.29              10       103.9
# 3    Australia               3678.75              17        96.4
# 7      Austria               2579.59              27        80.9
# 1       Sweden               2807.55              26        82.4
# 8      Finland               2818.03              22        90.2
#
#     monthly income($)  purchasing power index  currency rate  \
# 20               7364                   112.9         -1.095
# 13               6699                    97.4         -3.199
# 12               8538                   140.6          0.514
# ...

# %%
import plotly.express as px
fig = px.histogram(CR, x="COUNTRY", y="GDP")
fig.show()
# Out:
# <div>                            <div id="b43947bd-cad3-4ec0-a2c9-d0581663dc5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b43947bd-cad3-4ec0-a2c9-d0581663dc5a")) {                    Plotly.newPlot(                        "b43947bd-cad3-4ec0-a2c9-d0581663dc5a",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of GDP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Sri Lanka","Libya","India","Georgia","Bangladesh","Philippines","Kenya","China","Costa Rica","Kazakhstan"],"xaxis":"x","y":[3828,7330,2485,8120,2529,3726,1950,12614,16595,
# ...

# %%
IR = new.sort_values(by="inflation rate(%)", ascending=True).head(10)

# %%
IR
# Out:
#         COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 49    Sri Lanka                206.76              97        27.5
# 23   Costa Rica                964.67              39        67.2
# 53  El Salvador                501.07              54        49.0
# 0         China                938.91              49        51.5
# 46      Georgia                505.05              90        30.4
# 13      Ireland               3073.35              11       102.7
# 44      Morocco                418.32              63        40.6
# 8       Finland               2818.03              22        90.2
# 40        Qatar               4086.40              31        76.9
# 37     Thailand                584.14              81        32.2
#
#     monthly income($)  purchasing power index  currency rate  \
# 49                295                    16.0         12.100
# 23               1154                    25.7          5.112
# ...

# %%
import plotly.express as px
fig = px.histogram(IR, x="COUNTRY", y="inflation rate(%)")
fig.show()
# Out:
# <div>                            <div id="4f626f98-7ca2-44c6-9d97-fa07644c06d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f626f98-7ca2-44c6-9d97-fa07644c06d7")) {                    Plotly.newPlot(                        "4f626f98-7ca2-44c6-9d97-fa07644c06d7",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of inflation rate(%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Sri Lanka","Costa Rica","El Salvador","China","Georgia","Ireland","Morocco","Finland","Qatar","Thailand"],"xaxis":"x","y":[-0.8,-0.79,-0.07,0.3,0.3,0.7,0.8,0
# ...

# %%
SL = new.sort_values(by="skilled labour.SKILLED LABOUR", ascending=True).head(10)

# %%
SL
# Out:
#         COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 20   Luxembourg               5640.97              16        97.5
# 25      Estonia               1525.26              37        71.0
# 48      Albania                634.13              55        47.9
# 29      Croatia               1361.96              47        55.0
# 46      Georgia                505.05              90        30.4
# 40        Qatar               4086.40              31        76.9
# 58        Libya                326.36             104        24.4
# 23   Costa Rica                964.67              39        67.2
# 13      Ireland               3073.35              11       102.7
# 53  El Salvador                501.07              54        49.0
#
#     monthly income($)  purchasing power index  currency rate  \
# 20               7364                   112.9         -1.095
# 25               2270                    47.8         -3.006
# ...

# %%
import plotly.express as px
fig = px.histogram(SL, x="COUNTRY", y="skilled labour.SKILLED LABOUR")
fig.show()
# Out:
# <div>                            <div id="4be5c197-c1ac-44e0-87b3-7bf89ab0546d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4be5c197-c1ac-44e0-87b3-7bf89ab0546d")) {                    Plotly.newPlot(                        "4be5c197-c1ac-44e0-87b3-7bf89ab0546d",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of skilled labour.SKILLED LABOUR=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Luxembourg","Estonia","Albania","Croatia","Georgia","Qatar","Libya","Costa Rica","Ireland","El Salvador"],"xaxis":"x","y":[351903,752419,1387831,
# ...

# %%
Tech = new.sort_values(by="technology", ascending=True).head(10)

# %%
Tech
# Out:
#       COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 1      Sweden               2807.55              26        82.4
# 2   Singapore               4293.54              30        78.0
# 6     Germany               2984.93              29        79.5
# 8     Finland               2818.03              22        90.2
# 10    Belgium               2563.22              25        83.7
# 9      Canada               2818.53              21        90.7
# 3   Australia               3678.75              17        96.4
# 12     Norway               3286.54              20        90.8
# 13    Ireland               3073.35              11       102.7
# 15     France               2486.51              28        79.8
#
#     monthly income($)  purchasing power index  currency rate  \
# 1                5138                    93.2         -0.196
# 2                5883                   112.7          1.075
# 6                4498                    84.6         -0.305
# ...

# %%
import plotly.express as px
fig = px.histogram(Tech, x="COUNTRY", y="technology")
fig.show()
# Out:
# <div>                            <div id="b3976992-7c3a-4695-bc8f-9664bbdd6ce0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3976992-7c3a-4695-bc8f-9664bbdd6ce0")) {                    Plotly.newPlot(                        "b3976992-7c3a-4695-bc8f-9664bbdd6ce0",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of technology=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Sweden","Singapore","Germany","Finland","Belgium","Canada","Australia","Norway","Ireland","France"],"xaxis":"x","y":[2,3,7,8,10,11,12,13,14,15],"yaxis":"y","type":"
# ...

# %%
unemp = new.sort_values(by="unemployment", ascending=True).head(10)

# %%
unemp
# Out:
#                  COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 40                 Qatar               4086.40              31        76.9
# 37              Thailand                584.14              81        32.2
# 2              Singapore               4293.54              30        78.0
# 21                 Japan               2059.60              33        74.7
# 34                Mexico                653.23              45        60.7
# 27                Poland               1439.95              56        47.8
# 16               Belarus                522.44              94        29.3
# 6                Germany               2984.93              29        79.5
# 4   United Arab Emirates               3300.22              34        72.1
# 32              Malaysia                922.50              82        32.2
#
#     monthly income($)  purchasing power index  currency rate  \
# 40               5839                   113.5          1.558
# ...

# %%
import plotly.express as px
fig = px.histogram(unemp, x="COUNTRY", y="unemployment")
fig.show()
# Out:
# <div>                            <div id="14821393-5db3-491e-9583-df8ebc04bd4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14821393-5db3-491e-9583-df8ebc04bd4c")) {                    Plotly.newPlot(                        "14821393-5db3-491e-9583-df8ebc04bd4c",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of unemployment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Qatar","Thailand","Singapore","Japan","Mexico","Poland","Belarus","Germany","United Arab Emirates","Malaysia"],"xaxis":"x","y":[0.3,1.1,1.9,2.5,2.8,2.93,3.04,3.29
# ...

# %%
LR = new.sort_values(by="Litercay rate(%)", ascending=False).head(10)

# %%
LR
# Out:
#        COUNTRY  Monthy SALARY+TAX($)  cost of living  cost index  \
# 20  Luxembourg               5640.97              16        97.5
# 38      Serbia                776.48              53        49.1
# 8      Finland               2818.03              22        90.2
# 25     Estonia               1525.26              37        71.0
# 12      Norway               3286.54              20        90.8
# 16     Belarus                522.44              94        29.3
# 2    Singapore               4293.54              30        78.0
# 35     Romania                919.76              59        43.6
# 51  Azerbaijan                456.50              84        31.3
# 27      Poland               1439.95              56        47.8
#
#     monthly income($)  purchasing power index  currency rate  \
# 20               7364                   112.9         -1.095
# 38                836                    25.5          2.528
# 8                4449                    73.7         -0.957
# ...

# %%
import plotly.express as px
fig = px.histogram(LR, x="COUNTRY", y="Litercay rate(%)")
fig.show()
# Out:
# <div>                            <div id="c4c184b2-f06e-45ff-a75f-fdd4c399d2eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4c184b2-f06e-45ff-a75f-fdd4c399d2eb")) {                    Plotly.newPlot(                        "c4c184b2-f06e-45ff-a75f-fdd4c399d2eb",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"COUNTRY=%{x}\u003cbr\u003esum of Litercay rate(%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Luxembourg","Serbia","Finland","Estonia","Norway","Belarus","Singapore","Romania","Azerbaijan","Poland"],"xaxis":"x","y":[100.0,100.0,100.0,100.0,100.0,99.9,9
# ...

# %%
fig, axes = plt.subplots(2, 5,figsize=(25,20))
axes[0,0].bar(cl['COUNTRY'],cl['cost of living'],color='green')
axes[0,0].set_title('cost of living by Country')
axes[0,0].set_ylabel('cost of living')
axes[0,0].tick_params(axis='x',rotation=45)
axes[0,1].bar(PP['COUNTRY'], PP['purchasing power index'], color='red')
axes[0,1].set_title('Purchasing Power Index by Country')
axes[0,1].set_ylabel('purchasing power index')
axes[0,1].tick_params(axis='x', rotation=45)
axes[0,2].bar(CR['COUNTRY'], CR['currency rate'], color='blue')
axes[0,2].set_title('Currency rate of the Country')
axes[0,2].set_ylabel('currency rate')
axes[0,2].tick_params(axis='x', rotation=45)
axes[0,3].bar(GDP['COUNTRY'], GDP['GDP'], color='orange')
axes[0,3].set_title('GDP of the country')
axes[0,3].set_ylabel('GDP')
axes[0,3].tick_params(axis='x', rotation=45)
axes[0,4].bar(LR['COUNTRY'], LR['Litercay rate(%)'], color='yellow')
axes[0,4].set_title('Literacy rate')
axes[0,4].set_ylabel('Litercay rate(%)')
axes[0,4].tick_params(axis='x', rotation=45)
axes[1,0].bar(SL['COUNTRY'], SL['skilled labour.SKILLED LABOUR'], color='brown')
axes[1,0].set_title('skilled labour')
axes[1,0].set_ylabel('skilled labour.SKILLED LABOUR')
axes[1,0].tick_params(axis='x', rotation=45)
axes[1,1].bar(Tech['COUNTRY'], Tech['technology'],color='pink')
axes[1,1].set_title('Technology by Country')
axes[1,1].set_ylabel('technology')
axes[1,1].tick_params(axis='x', rotation=45)
axes[1,2].bar(unemp['COUNTRY'],unemp['unemployment'],color='purple')
axes[1,2].set_title('Unemployment by Country')
axes[1,2].set_ylabel('unemployment')
axes[1,2].tick_params(axis='x', rotation=45)
axes[1,3].bar(IR['COUNTRY'],IR['inflation rate(%)'],color='purple')
axes[1,3].set_title('inflation rate(%) by Country')
axes[1,3].set_ylabel('inflation rate(%)')
axes[1,3].tick_params(axis='x', rotation=45)
axes[1,4].bar(l['COUNTRY'],l['Monthy SALARY+TAX($)'],color='purple')
axes[1,4].set_title('Average salary by Country')
axes[1,4].set_ylabel('Monthy SALARY+TAX($)')
axes[1,4].tick_params(axis='x', rotation=45)

# %%
a=l['COUNTRY'].reset_index()
a=a.drop(columns=['index'])
a
# Out:
#                 COUNTRY
# 0            Luxembourg
# 1             Singapore
# 2                 Qatar
# 3             Australia
# 4               Denmark
# 5  United Arab Emirates
# 6                Norway
# 7        United Kingdom
# 8               Ireland
# 9               Germany

# %%
b=cl['COUNTRY'].reset_index()
b=b.drop(columns=['index'])
b
# Out:
#           COUNTRY
# 0          Israel
# 1         Denmark
# 2         Ireland
# 3      Luxembourg
# 4       Australia
# 5     New Zealand
# 6  United Kingdom
# 7          Norway
# 8          Canada
# 9         Finland

# %%
from functools import reduce



# Finding a common element
result = list(reduce(set.intersection, map(set, [a.COUNTRY, b.COUNTRY])))

# Display Result
print("Common element:\n",result)
# Out:
# Common element:
#  ['Luxembourg', 'Australia', 'Denmark', 'Norway', 'United Kingdom', 'Ireland']

# %%
#c=LR['COUNTRY'].reset_index()
#c=c.drop(columns=['index'])
#c

# %%
d=SL['COUNTRY'].reset_index()
d=d.drop(columns=['index'])
d
# Out:
#        COUNTRY
# 0   Luxembourg
# 1      Estonia
# 2      Albania
# 3      Croatia
# 4      Georgia
# 5        Qatar
# 6        Libya
# 7   Costa Rica
# 8      Ireland
# 9  El Salvador

# %%
f=GDP['COUNTRY'].reset_index()
f=f.drop(columns=['index'])
f
# Out:
#       COUNTRY
# 0  Luxembourg
# 1     Ireland
# 2      Norway
# 3       Qatar
# 4   Singapore
# 5     Denmark
# 6   Australia
# 7     Austria
# 8      Sweden
# 9     Finland

# %%
from functools import reduce



# Finding a common element
result = list(reduce(set.intersection, map(set, [a.COUNTRY, b.COUNTRY, d.COUNTRY, f.COUNTRY])))

# Display Result
print("Common element:\n",result)
# Out:
# Common element:
#  ['Luxembourg', 'Ireland']

# %%
The analysis highlights Luxembourg and Ireland as key migration destinations, driven by economic growth, political stability, and high living standards. However, distinct factors influence migration patterns in each country.

Luxembourg
Luxembourg attracts a highly skilled international workforce, particularly in finance, IT, and EU-related sectors, due to its status as a financial hub and EU administrative center. Its multilingual environment and proximity to neighboring countries make it appealing, especially for cross-border workers. However, high housing costs and limited urban space may slow migration growth unless addressed through policy interventions.

Ireland
Ireland’s strong appeal stems from its thriving tech industry and multinational corporations, which create high demand for global talent. As an English-speaking nation, it is especially attractive to non-EU migrants. While immigration remains closely tied to economic performance, rising housing costs and infrastructure constraints could impact future inflows. However, Ireland’s relatively open immigration policies contribute to a diverse and globalized labor market.

Comparison
Both nations rely on skilled migration, but Luxembourg’s smaller, finance-driven market creates a more specialized migration pattern, while Ireland’s broader tech and service sectors attract a more diverse migrant population.

Future Outlook
To remain attractive to migrants, both countries must address housing and cost-of-living challenges. Luxembourg is likely to maintain its niche appeal, whereas Ireland is poised for further demographic diversification, particularly in tech-driven regions.
